# %%
import torch.nn as nn
import numpy as np

pi_net = nn.Sequential(
              nn.Linear(obs_dim, 64),
              nn.Tanh(),
              nn.Linear(64, 64),
              nn.Tanh(),
              nn.Linear(64, act_dim)
            )

# %%
obs_dim = 10
obs = np.random.rand(obs_dim,obs_dim)
obs
# Out:
# array([[0.22972082, 0.82547453, 0.67391405, 0.4761481 , 0.5950304 ,
#         0.80200047, 0.7510764 , 0.88628078, 0.6751694 , 0.44717968],
#        [0.09554814, 0.73245195, 0.37139981, 0.82850845, 0.63013791,
#         0.04815998, 0.80356332, 0.52913303, 0.60510747, 0.17477992],
#        [0.31162401, 0.72071   , 0.8632286 , 0.68588816, 0.51407288,
#         0.37067422, 0.4423624 , 0.81528047, 0.36381815, 0.36987021],
#        [0.67611293, 0.75514156, 0.24071518, 0.44283617, 0.1785316 ,
#         0.35602666, 0.7066193 , 0.89403999, 0.82259383, 0.78105737],
#        [0.3506553 , 0.69577556, 0.46434139, 0.84109049, 0.70799704,
#         0.8943826 , 0.6439523 , 0.63093086, 0.86277786, 0.90687087],
#        [0.20420181, 0.64540708, 0.73769547, 0.19698926, 0.12137454,
#         0.50492765, 0.03973028, 0.6417774 , 0.60208617, 0.63222621],
#        [0.796772  , 0.95919124, 0.51145622, 0.39603301, 0.655115  ,
#         0.05974143, 0.76078606, 0.56123943, 0.04659695, 0.07133078],
#        [0.52863319, 0.7062886 , 0.1773971 , 0.57224627, 0.8161068 ,
#         0.67047118, 0.08589904, 0.6743247 , 0.89888833, 0.84803035],
#        [0.41039535, 0.53461125, 0.23549839, 0.49987676, 0.46121828,
#         0.47776635, 0.71835256, 0.05896684, 0.78019818, 0.93275018],
#        [0.89789204, 0.7573215 , 0.10333847, 0.70642332, 0.15175975,
#         0.60037939, 0.18442785, 0.60559243, 0.39044579, 0.23774424]])

# %%
act_dim = 10

# %%
pi_net = nn.Sequential(
              nn.Linear(obs_dim, 64),
              nn.Tanh(),
              nn.Linear(64, 64),
              nn.Tanh(),
              nn.Linear(64, act_dim)
            )

# %%
obs_tensor = torch.as_tensor(obs, dtype=torch.float32)
actions = pi_net(obs_tensor)

# %%
actions
# Out:
# tensor([[-0.0824, -0.0306,  0.1844, -0.1819, -0.0477,  0.1583, -0.0743, -0.0562,
#           0.0801, -0.1975],
#         [ 0.0130,  0.0313,  0.2361, -0.1722, -0.0336,  0.1383, -0.1215,  0.0058,
#           0.0149, -0.1674],
#         [-0.0593, -0.0444,  0.1763, -0.1782, -0.0304,  0.1177, -0.1031,  0.0080,
#           0.0767, -0.1328],
#         [-0.1022, -0.0532,  0.2179, -0.1799, -0.0132,  0.1976, -0.0567, -0.0116,
#          -0.0096, -0.1827],
#         [-0.0656, -0.0326,  0.1988, -0.1919, -0.0596,  0.1979, -0.0524, -0.0094,
#           0.0626, -0.2293],
#         [-0.1007, -0.0843,  0.1566, -0.1716, -0.0268,  0.1502, -0.0183,  0.0202,
#           0.0410, -0.1362],
#         [-0.0434, -0.0440,  0.2135, -0.1593,  0.0017,  0.0853, -0.1392,  0.0004,
#           0.0030, -0.1321],
#         [-0.0431, -0.0552,  0.2194, -0.2345, -0.0494,  0.2112, -0.0688,  0.0262,
#           0.0535, -0.2366],
#         [-0.0382, -0.0470,  0.2078, -0.1552, -0.0409,  0.1668, -0.0157,  0.0348,
#          -0.0395, -0.2140],
#         [-0.1296, -0.0475,  0.1989, -0.1771,  0.0027,  0.2004, -0.0450,  0.0831,
#          -0.0094, -0.1760]], grad_fn=<AddmmBackward>)
